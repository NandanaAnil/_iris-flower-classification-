# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
iris = pd.read_csv('iris-flower-dataset.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.head(60)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# 5            5.4          3.9           1.7          0.4      Iris-setosa
# 6            4.6          3.4           1.4          0.3      Iris-setosa
# 7            5.0          3.4           1.5          0.2      Iris-setosa
# 8            4.4          2.9           1.4          0.2      Iris-setosa
# 9            4.9          3.1           1.5          0.1      Iris-setosa
# 10           5.4          3.7           1.5          0.2      Iris-setosa
# 11           4.8          3.4           1.6          0.2      Iris-setosa
# ...

# %%
iris.tail(60)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 90            5.5          2.6           4.4          1.2  Iris-versicolor
# 91            6.1          3.0           4.6          1.4  Iris-versicolor
# 92            5.8          2.6           4.0          1.2  Iris-versicolor
# 93            5.0          2.3           3.3          1.0  Iris-versicolor
# 94            5.6          2.7           4.2          1.3  Iris-versicolor
# 95            5.7          3.0           4.2          1.2  Iris-versicolor
# 96            5.7          2.9           4.2          1.3  Iris-versicolor
# 97            6.2          2.9           4.3          1.3  Iris-versicolor
# 98            5.1          2.5           3.0          1.1  Iris-versicolor
# 99            5.7          2.8           4.1          1.3  Iris-versicolor
# 100           6.3          3.3           6.0          2.5   Iris-virginica
# ...

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.countplot(x='species', data = iris, palette = 'Set2')
plt.title('Species Count')
plt.xlabel('species')
plt.ylabel('Count')
plt.show
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10352\2809213035.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='species', data = iris, palette = 'Set2')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(14,7))
sns.barplot(x='sepal_length', y='petal_length', data = iris, color = 'pink')
plt.title('Flower Analysis')
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
iris['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
iris.replace({'species':{'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2}}, inplace = True)
# Out:
# C:\Users\Nandana\AppData\Local\Temp\ipykernel_10352\2415478778.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris.replace({'species':{'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2}}, inplace = True)

# %%
iris.head(60)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 0            5.1          3.5           1.4          0.2        0
# 1            4.9          3.0           1.4          0.2        0
# 2            4.7          3.2           1.3          0.2        0
# 3            4.6          3.1           1.5          0.2        0
# 4            5.0          3.6           1.4          0.2        0
# 5            5.4          3.9           1.7          0.4        0
# 6            4.6          3.4           1.4          0.3        0
# 7            5.0          3.4           1.5          0.2        0
# 8            4.4          2.9           1.4          0.2        0
# 9            4.9          3.1           1.5          0.1        0
# 10           5.4          3.7           1.5          0.2        0
# 11           4.8          3.4           1.6          0.2        0
# 12           4.8          3.0           1.4          0.1        0
# ...

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.boxplot(data=iris, ax=ax)
# Out:
# <Axes: >

# %%
Q1 = iris.quantile(0.25)
Q3 = iris.quantile(0.75)

#Calculate IQR - Inter Quartile Range 
IQR = Q3 - Q1

#Determine the outlier boundaries 
lower_bound = Q1 - 1.5 * IQR 
upper_bound = Q3 + 1.5 * IQR

#Create a mask for data within the IQR boundaries 
mask = ~((iris < lower_bound) | (iris > upper_bound)).any(axis=1)

#Remove outliers 
cleaned_data = iris[mask]

# %%
fig, ax = plt.subplots(figsize=(20,20))
sns.boxplot(cleaned_data, ax=ax)
# Out:
# <Axes: >

# %%
cleaned_data.shape
# Out:
# (146, 5)

# %%
correlation = cleaned_data.corr()
correlation
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   species
# sepal_length      1.000000    -0.113977      0.879374     0.822577  0.788053
# sepal_width      -0.113977     1.000000     -0.397123    -0.329782 -0.397265
# petal_length      0.879374    -0.397123      1.000000     0.961755  0.947469
# petal_width       0.822577    -0.329782      0.961755     1.000000  0.955549
# species           0.788053    -0.397265      0.947469     0.955549  1.000000

# %%
sns.heatmap(correlation, cbar=True, square=True, fmt='.2f', annot=True, annot_kws={'size':8},cmap='Pastel1')
# Out:
# <Axes: >

# %%
cleaned_data['species'].value_counts()
# Out:
# species
# 2    50
# 1    49
# 0    47
# Name: count, dtype: int64

# %%
sns.countplot(x='species', data=cleaned_data)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
x = cleaned_data.drop('species', axis=1)
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [146 rows x 4 columns]

# %%
y = cleaned_data['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 146, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 2)

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
train_data_predict = model.predict(x_train)
train_data_accuracy = accuracy_score(y_train, train_data_predict)
print("Accuracy of training data:", train_data_accuracy)
# Out:
# Accuracy of training data: 1.0

# %%
test_data_predict = model.predict(x_test)
test_data_accuracy = accuracy_score(y_test, test_data_predict)
print("Accuracy of testing data:", test_data_accuracy)
# Out:
# Accuracy of testing data: 1.0

# %%
cleaned_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
cm = confusion_matrix(test_data_predict, y_test)
cm
# Out:
# array([[11,  0,  0],
#        [ 0, 11,  0],
#        [ 0,  0,  8]], dtype=int64)

# %%
sns.heatmap(cm, annot = True, annot_kws = {'size':20}, fmt = '.2f', cmap = 'Pastel1', square = True, 
           xticklabels = ['predicted_iris_setosa', 'predicted_iris_versicolor', 'predicted_iris_virginica'],
           yticklabels = ['actual_iris_setosa', 'actual_iris_versicolor', 'actual_iris_virginica'])
plt.xlabel('predicted_area')
plt.ylabel('actual_area')
plt.title('confusion_matrix')
plt.show()

# %%
print(classification_report(test_data_predict, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
new_data = (5.5,2.3,4.0,1.3)
new_data_as_np = np.asarray(new_data)
new_data_reshaped = new_data_as_np.reshape(1,-1)
prediction = model.predict(new_data_reshaped)
if(prediction[0] ==  0):
    print("The species is Iris-setosa")
elif(prediction[0] == 1):
    print("The species is Iris-versicolor")
elif(prediction[0] == 2):
    print('The species is Iris-viriginica')
# Out:
# The species is Iris-versicolor
# C:\Users\Nandana\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
